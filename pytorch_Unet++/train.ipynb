# %%
# %run train_unet++.py
# Out:
# - loss: 0.021746
# 0.3370 --- loss: 0.011959
# 0.3378 --- loss: 0.021215
# 0.3387 --- loss: 0.015894
# 0.3396 --- loss: 0.015013
# 0.3404 --- loss: 0.011382
# 0.3413 --- loss: 0.028231
# 0.3422 --- loss: 0.018859
# 0.3430 --- loss: 0.041574
# 0.3439 --- loss: 0.023426
# 0.3448 --- loss: 0.011465
# 0.3456 --- loss: 0.009960
# 0.3465 --- loss: 0.014884
# 0.3474 --- loss: 0.016209
# 0.3482 --- loss: 0.014904
# 0.3491 --- loss: 0.025175
# 0.3500 --- loss: 0.013340
# 0.3508 --- loss: 0.013731
# 0.3517 --- loss: 0.011717
# 0.3526 --- loss: 0.047381
# 0.3535 --- loss: 0.031251
# 0.3543 --- loss: 0.016715
# 0.3552 --- loss: 0.018937
# 0.3561 --- loss: 0.010910
# 0.3569 --- loss: 0.013166
# 0.3578 --- loss: 0.015978
# 0.3587 --- loss: 0.016608
# 0.3595 --- loss: 0.021732
# 0.3604 --- loss: 0.015602
# 0.3613 --- loss: 0.011008
# 0.3621 --- loss: 0.016516
# 0.3630 --- loss: 0.026508
# 0.3639 --- loss: 0.030611
# 0.3647 --- loss: 0.022762
# 0.3656 --- loss: 0.015358
# 0.3665 --- loss: 0.015511
# ...

# %%
writer.add_scalar('test', lr+1, epoch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-6b9a3f4db6ee> in <module>()
# ----> 1 writer.add_scalar('test', lr+1, epoch)
#
# NameError: name 'lr' is not defined
